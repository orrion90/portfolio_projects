# %%
import pandas as pd

# %%
df = pd.read_excel('/git/Num_of_tenders/tenders_lots2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-353c7e83ce90> in <module>
# ----> 1 df = pd.read_excel('tenders_lots2.xlsx')
#
# c:\users\ohrem\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\users\ohrem\appdata\local\programs\python\python39\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
#     335         should_close = True
# --> 336         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     337     elif engine and engine != io.engine:
#     338         raise ValueError(
#
# c:\users\ohrem\appdata\local\programs\python\python39\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1069                 ext = "xls"
#    1070             else:
# -> 1071                 ext = inspect_excel_format(
#    1072                     content=path_or_buffer, storage_options=storage_options
#    1073                 )
#
# c:\users\ohrem\appdata\local\programs\python\python39\lib\site-packages\pandas\io\excel\_base.py in inspect_excel_format(path, content, storage_options)
#     947     assert content_or_path is not None
#     948
# --> 949     with get_handle(
#     950         content_or_path, "rb", storage_options=storage_options, is_text=False
#     951     ) as handle:
#
# c:\users\ohrem\appdata\local\programs\python\python39\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     649         else:
#     650             # Binary mode
# --> 651             handle = open(handle, ioargs.mode)
#     652         handles.append(handle)
#     653
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tenders_lots2.xlsx'

# %%
df = df.rename(columns = {'Ідентифікатор лота': 'lot_id',
                     'Лот': 'lot',
                     'Очікувана вартість': 'expected_cost',
                     'Процедура закупівлі': 'procurement_procedure',
                     'Статуси процедур': 'status_procedures',
                     'Статус лота': 'lot_status',
                     '...': 'web_site',
                     'Організатор' : 'organizer',
                     'Переможець' : 'winner',
                     'Ціна за одиницю': 'price_per_unit',
                     'Одиниця виміру': 'unit_of_measure',
                     'Класифікація CPV': 'classification_cpv',
                     'Кіль-ть питань': 'num_questions',
                     'Кіль-ть унікальних учасників лота': 'num_of_unique_participants',
                     'Кількість дискваліфікацій лота': 'num_of_disq',
                     'Кількість скарг лота': 'num_of_complains',
                     'Дата публікації процедури': 'date_of_publication_of_the_procedure'})

# %%
df['organizer'].
# Out:
# 19820

# %%
filt = (df['winner'].apply(len) < 2)

# %%
df[filt].groupby('lot_status').count()
# Out:
#                           lot_id    lot  expected_cost  procurement_procedure  \
# lot_status
# Неуспішний лот закупівлі   10783  10783          10783                  10783
# Скасовано лот закупівлі      384    384            384                    384
#
#                           status_procedures  web_site  organizer  winner  \
# lot_status
# Неуспішний лот закупівлі              10783     10783      10783   10783
# Скасовано лот закупівлі                 384       384        384     384
#
#                           price_per_unit  unit_of_measure  classification_cpv  \
# lot_status
# Неуспішний лот закупівлі           10783            10783               10783
# Скасовано лот закупівлі              384              384                 384
#
#                           num_questions  num_of_unique_participants  \
# lot_status
# Неуспішний лот закупівлі          10783                       10783
# Скасовано лот закупівлі             384                         384
#
#                           num_of_disq  num_of_complaints  \
# lot_status
# Неуспішний лот закупівлі        10783              10783
# Скасовано лот закупівлі           384                384
#
#                           date_of_publication_of_the_procedure
# lot_status
# Неуспішний лот закупівлі                                 10783
# Скасовано лот закупівлі                                    384

# %%
filt = (df['winner'].apply(len) < 2)
df.drop(df[filt].index, inplace=True)

# %%
df.shape[0]
# Out:
# 308746

# %%
df.isna().sum()
# Out:
# lot_id                                  0
# lot                                     0
# expected_cost                           0
# procurement_procedure                   0
# status_procedures                       0
# lot_status                              0
# web_site                                0
# organizer                               0
# winner                                  0
# price_per_unit                          0
# unit_of_measure                         0
# classification_cpv                      0
# num_questions                           0
# num_of_unique_participants              0
# num_of_disq                             0
# num_of_complaints                       0
# date_of_publication_of_the_procedure    0
# dtype: int64

# %%
res_df = df \
    .groupby(['organizer', 'winner'], as_index=False) \
    .aggregate({'lot_id': 'count'}) \
    .sort_values('lot_id', ascending=False)

# %%
res_df
# Out:
#                                                 organizer  \
# 130559  Комунальне підприємство «Керуюча компанія з об...
# 38892   ДЕПАРТАМЕНТ ГУМАНІТАРНОЇ ПОЛІТИКИ ДНІПРОВСЬКОЇ...
# 126261  Комунальне підприємство "Дирекція з капітально...
# 126266  Комунальне підприємство "Дирекція з капітально...
# 126256  Комунальне підприємство "Дирекція з капітально...
# ...                                                   ...
# 72063   КОМУНАЛЬНА УСТАНОВА "НОВОБОРІВСЬКИЙ ДИТЯЧИЙ БУ...
# 72064   КОМУНАЛЬНА УСТАНОВА "НОВОБОРІВСЬКИЙ ДИТЯЧИЙ БУ...
# 72065   КОМУНАЛЬНА УСТАНОВА "НОВОБОРІВСЬКИЙ ДИТЯЧИЙ БУ...
# 72068   КОМУНАЛЬНА УСТАНОВА "НОВОБОРІВСЬКИЙ ДИТЯЧИЙ БУ...
# 188600  інститут проблем ринку та економіко екологічни...
#
#                                                    winner  lot_id
# 130559  Товариство з обмеженою відповідальністю "ЕЛЕВЕ...     327
# 38892              ТОВ "КОНТРАКТ ПРОДРЕЗЕРВ 5" | 35601826     310
# 126261    ТОВ "ДИТЯЧІ ТА СПОРТИВНІ МАЙДАНЧИКИ" | 37095763     293
# 126266  Товариство з обмеженою відповідальністю "СТРІТ...     225
# 126256  Приватне підприємство "Деревообробний завод "Б...     209
# ...                                                   ...     ...
# 72063           САДОВНІКОВ МИКОЛА СЕРГІЙОВИЧ | 3453815090       1
# 72064                      ТОВ "А СЕРВІС ГРУП" | 41371246       1
# 72065                              ТОВ "АНБАР" | 41301708       1
# 72068                        ТОВ "ВІКТРЕЙДИНГ" | 39460635       1
# 188600       ФОП Омельченко Вадим Григорович | 2209219819       1
#
# [188601 rows x 3 columns]

# %%
res_df.drop_duplicates(subset = ['organizer'], inplace=True)

# %%
res_df.rename(columns={'organizer': 'Організатор', \
                       'winner': 'Переможець', \
                       'lot_id': 'Кількість виграних лотів'}, inplace=True)

# %%
res_df
# Out:
#                                               Організатор  \
# 130559  Комунальне підприємство «Керуюча компанія з об...
# 38892   ДЕПАРТАМЕНТ ГУМАНІТАРНОЇ ПОЛІТИКИ ДНІПРОВСЬКОЇ...
# 126261  Комунальне підприємство "Дирекція з капітально...
# 177218  Управління освіти Херсонської міської ради | 0...
# 53329   Департамент житлово - комунального господарств...
# ...                                                   ...
# 72007   КОМУНАЛЬНА УСТАНОВА "КОМПЛЕКСНА ДИТЯЧО-ЮНАЦЬКА...
# 72022   КОМУНАЛЬНА УСТАНОВА "МІЛОВСЬКИЙ РАЙОННИЙ ЦЕНТР...
# 72016   КОМУНАЛЬНА УСТАНОВА "ЛІСОВОГРИНІВЕЦЬКА МІСЦЕВА...
# 72017   КОМУНАЛЬНА УСТАНОВА "ЛУГАНСЬКИЙ ОБЛАСНИЙ ФІЗКУ...
# 72052   КОМУНАЛЬНА УСТАНОВА "МЕМОРІАЛЬНИЙ МУЗЕЙ ГІДНОС...
#
#                                                Переможець  \
# 130559  Товариство з обмеженою відповідальністю "ЕЛЕВЕ...
# 38892              ТОВ "КОНТРАКТ ПРОДРЕЗЕРВ 5" | 35601826
# 126261    ТОВ "ДИТЯЧІ ТА СПОРТИВНІ МАЙДАНЧИКИ" | 37095763
# 177218  ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ПІВДЕ...
# 53329                        ПрАТ "Херсонліфт" | 03565866
# ...                                                   ...
# 72007   ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ ТОРГОВ...
# 72022                       ТОВ СТРОЙГАРАНТ-СК | 40785391
# 72016   ТОВАРИСТВО З ОБМЕЖЕНОЮ ВІДПОВІДАЛЬНІСТЮ "ЛІВАЙ...
# 72017                       ПП "ОККО КОНТРАКТ" | 36248687
# 72052                       ТОВ "ІНТЕКС ЦЕНТР" | 41675618
#
#         Кількість виграних лотів
# 130559                       327
# 38892                        310
# 126261                       293
# 177218                       175
# 53329                        148
# ...                          ...
# 72007                          1
# 72022                          1
# 72016                          1
# 72017                          1
# 72052                          1
#
# [19820 rows x 3 columns]

# %%
res_df.to_excel('task1_corr3.xlsx', index=False)
